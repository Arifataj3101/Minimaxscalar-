# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/salary_data (2) (1) (1).csv')

# %%
x = dataset.iloc[:,:-1]

# %%
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3 ,random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(x_train)

scaler.transform(x_train)
# Out:
# array([[0.19148936],
#        [0.42553191],
#        [0.22340426],
#        [0.36170213],
#        [0.75531915],
#        [0.60638298],
#        [0.0212766 ],
#        [1.        ],
#        [0.20212766],
#        [0.11702128],
#        [0.5106383 ],
#        [0.5212766 ],
#        [0.27659574],
#        [0.22340426],
#        [0.84042553],
#        [0.09574468],
#        [0.        ],
#        [0.63829787],
#        [0.40425532],
#        [0.30851064]])
